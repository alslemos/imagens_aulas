# %% [markdown]
# <a href="https://colab.research.google.com/github/alslemos/imagens_aulas/blob/main/aprendendo_geopandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
import matplotlib as plt
import pandas as pd

# %%
# lendo o arquivo

gdf = gpd.read_file("/content/drive/MyDrive/estudo/schools-list.geojson")
print(gdf)

gdf = gdf.set_index("Address 1")
gdf["area"] = gdf.UPRN
gdf["area"]
# Out:
#     DfE number                             Establishment            Phase  \
# 0         2005                        Abbey Park Academy          Primary
# 1         5201           All Saints' CofE Primary School          Primary
# 2         2093        Ash Green Community Primary School          Primary
# 3         2040  Bailiffe Bridge Junior and Infant School          Primary
# 4         3321         Barkisland CofE VA Primary School          Primary
# ..         ...                                       ...              ...
# 96        2016                         West Vale Academy          Primary
# 97        2031               Whitehill Community Academy          Primary
# 98        2046               Withinfields Primary School          Primary
# 99        7008                          Wood Bank School  Special primary
# 100       2081                  Woodhouse Primary School          Primary
#
#                        Status   Head title            Head name  \
# ...

# %%
plt.rcParams['figure.figsize'] = [20, 10] # aumentando o gráfico
gdf.plot(color = 'green', edgecolor = 'black', linewidth = 0.1)
# Out:
# <Axes: >
